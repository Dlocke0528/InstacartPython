# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# import orders products combined DF
df_merged_large = pd.read_csv(r"C:\Users\danie\_orders_products\orders_products_combined.csv")

# %%
df_merged_large.shape
# Out:
# (32434489, 12)

# %%
# import products wrangled Df_1
df_orders = pd.read_csv(r"C:\Users\danie\_orders_products\products_wrangled.csv")

# %%
# merge the two frames
frames=[df_merged_large, df_orders]

# %%
df_concat = pd.concat(frames)

# %%
df_concat
# Out:
#        Unnamed: 0   order_id  user_id eval_set  order_number  order_dow  \
# 0               0  2539329.0      1.0    prior           1.0        2.0
# 1               1  2539329.0      1.0    prior           1.0        2.0
# 2               2  2539329.0      1.0    prior           1.0        2.0
# 3               3  2539329.0      1.0    prior           1.0        2.0
# 4               4  2539329.0      1.0    prior           1.0        2.0
# ...           ...        ...      ...      ...           ...        ...
# 49667       49688        NaN      NaN      NaN           NaN        NaN
# 49668       49689        NaN      NaN      NaN           NaN        NaN
# 49669       49690        NaN      NaN      NaN           NaN        NaN
# 49670       49691        NaN      NaN      NaN           NaN        NaN
# 49671       49692        NaN      NaN      NaN           NaN        NaN
#
#        order_hour_of_day  days_since_prior_order  product_id  \
# 0                    8.0                     NaN         196
# 1                    8.0                     NaN       14084
# 2                    8.0                     NaN       12427
# 3                    8.0                     NaN       26088
# 4                    8.0                     NaN       26405
# ...                  ...                     ...         ...
# 49667                NaN                     NaN       49684
# 49668                NaN                     NaN       49685
# 49669                NaN                     NaN       49686
# 49670                NaN                     NaN       49687
# 49671                NaN                     NaN       49688
#
#        add_to_cart_order  reordered _merge  \
# 0                    1.0        0.0   both
# 1                    2.0        0.0   both
# 2                    3.0        0.0   both
# 3                    4.0        0.0   both
# 4                    5.0        0.0   both
# ...                  ...        ...    ...
# 49667                NaN        NaN    NaN
# 49668                NaN        NaN    NaN
# 49669                NaN        NaN    NaN
# 49670                NaN        NaN    NaN
# 49671                NaN        NaN    NaN
#
#                                      product_name  aisle_id  department_id  \
# 0                                             NaN       NaN            NaN
# 1                                             NaN       NaN            NaN
# 2                                             NaN       NaN            NaN
# 3                                             NaN       NaN            NaN
# 4                                             NaN       NaN            NaN
# ...                                           ...       ...            ...
# 49667   Vodka, Triple Distilled, Twist of Vanilla     124.0            5.0
# 49668          En Croute Roast Hazelnut Cranberry      42.0            1.0
# 49669                            Artisan Baguette     112.0            3.0
# 49670  Smartblend Healthy Metabolism Dry Cat Food      41.0            8.0
# 49671                      Fresh Foaming Cleanser      73.0           11.0
#
#        prices
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 49667     5.3
# 49668     3.1
# 49669     7.8
# 49670     4.7
# 49671    13.5
#
# [32484161 rows x 16 columns]

# %%
df_concat = pd.concat(frames, axis =1)

# %%
df_concat
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  1   2539329        1    prior             1          2
# 2                  2   2539329        1    prior             1          2
# 3                  3   2539329        1    prior             1          2
# 4                  4   2539329        1    prior             1          2
# ...              ...       ...      ...      ...           ...        ...
# 32434484    32434484   2977660   206209    prior            13          1
# 32434485    32434485   2977660   206209    prior            13          1
# 32434486    32434486   2977660   206209    prior            13          1
# 32434487    32434487   2977660   206209    prior            13          1
# 32434488    32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# 2                         8                     NaN       12427
# 3                         8                     NaN       26088
# 4                         8                     NaN       26405
# ...                     ...                     ...         ...
# 32434484                 12                     7.0       14197
# 32434485                 12                     7.0       38730
# 32434486                 12                     7.0       31477
# 32434487                 12                     7.0        6567
# 32434488                 12                     7.0       22920
#
#           add_to_cart_order  reordered _merge  Unnamed: 0  product_id  \
# 0                         1          0   both         0.0         1.0
# 1                         2          0   both         1.0         2.0
# 2                         3          0   both         2.0         3.0
# 3                         4          0   both         3.0         4.0
# 4                         5          0   both         4.0         5.0
# ...                     ...        ...    ...         ...         ...
# 32434484                  5          1   both         NaN         NaN
# 32434485                  6          0   both         NaN         NaN
# 32434486                  7          0   both         NaN         NaN
# 32434487                  8          0   both         NaN         NaN
# 32434488                  9          0   both         NaN         NaN
#
#                                                product_name  aisle_id  \
# 0                                Chocolate Sandwich Cookies      61.0
# 1                                          All-Seasons Salt     104.0
# 2                      Robust Golden Unsweetened Oolong Tea      94.0
# 3         Smart Ones Classic Favorites Mini Rigatoni Wit...      38.0
# 4                                 Green Chile Anytime Sauce       5.0
# ...                                                     ...       ...
# 32434484                                                NaN       NaN
# 32434485                                                NaN       NaN
# 32434486                                                NaN       NaN
# 32434487                                                NaN       NaN
# 32434488                                                NaN       NaN
#
#           department_id  prices
# 0                  19.0     5.8
# 1                  13.0     9.3
# 2                   7.0     4.5
# 3                   1.0    10.5
# 4                  13.0     4.3
# ...                 ...     ...
# 32434484            NaN     NaN
# 32434485            NaN     NaN
# 32434486            NaN     NaN
# 32434487            NaN     NaN
# 32434488            NaN     NaN
#
# [32434489 rows x 18 columns]

# %%
df_merged = df_merged_large.merge(df_orders, on = 'product_id')

# %%
df_merged
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    5   2398795        1    prior             2          3
# 2                   11    473747        1    prior             3          3
# 3                   16   2254736        1    prior             4          4
# 4                   21    431534        1    prior             5          4
# ...                ...       ...      ...      ...           ...        ...
# 32404854      31866630   1320836   202557    prior            17          2
# 32404855      31866648     31526   202557    prior            18          5
# 32404856      32011605    758936   203436    prior             1          2
# 32404857      32011621   2745165   203436    prior             2          3
# 32404858      32313072   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# 2                        12                    21.0         196
# 3                         7                    29.0         196
# 4                        15                    28.0         196
# ...                     ...                     ...         ...
# 32404854                 15                     1.0       43553
# 32404855                 11                     3.0       43553
# 32404856                  7                     NaN       42338
# 32404857                  5                    15.0       42338
# 32404858                 14                     NaN       28818
#
#           add_to_cart_order  reordered _merge  Unnamed: 0_y  \
# 0                         1          0   both           195
# 1                         1          1   both           195
# 2                         1          1   both           195
# 3                         1          1   both           195
# 4                         1          1   both           195
# ...                     ...        ...    ...           ...
# 32404854                  2          1   both         43557
# 32404855                  2          1   both         43557
# 32404856                  4          0   both         42342
# 32404857                 16          1   both         42342
# 32404858                  8          0   both         28820
#
#                            product_name  aisle_id  department_id  prices
# 0                                  Soda        77              7     9.0
# 1                                  Soda        77              7     9.0
# 2                                  Soda        77              7     9.0
# 3                                  Soda        77              7     9.0
# 4                                  Soda        77              7     9.0
# ...                                 ...       ...            ...     ...
# 32404854            Orange Energy Shots        64              7     3.7
# 32404855            Orange Energy Shots        64              7     3.7
# 32404856          Zucchini Chips, Pesto        50             19     6.9
# 32404857          Zucchini Chips, Pesto        50             19     6.9
# 32404858  Hot Oatmeal Multigrain Raisin       130             14    10.3
#
# [32404859 rows x 17 columns]

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             5   2398795        1    prior             2          3
# 2            11    473747        1    prior             3          3
# 3            16   2254736        1    prior             4          4
# 4            21    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered _merge  Unnamed: 0_y product_name  aisle_id  department_id  \
# 0          0   both           195         Soda        77              7
# 1          1   both           195         Soda        77              7
# 2          1   both           195         Soda        77              7
# 3          1   both           195         Soda        77              7
# 4          1   both           195         Soda        77              7
#
#    prices
# 0     9.0
# 1     9.0
# 2     9.0
# 3     9.0
# 4     9.0

# %%
df_merged.shape
# Out:
# (32404859, 17)

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both    32404859
# Name: count, dtype: int64

# %%
df_concat= df_merged_large.merge(df_orders, on = 'product_id', indicator=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df_concat= df_merged_large.merge(df_orders, on = 'product_id', indicator=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9843, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9824 @Substitution("")
#    9825 @Appender(_merge_doc, indents=2)
#    9826 def merge(
#    (...)
#    9839     validate: str | None = None,
#    9840 ) -> DataFrame:
#    9841     from pandas.core.reshape.merge import merge
# -> 9843     return merge(
#    9844         self,
#    9845         right,
#    9846         how=how,
#    9847         on=on,
#    9848         left_on=left_on,
#    9849         right_on=right_on,
#    9850         left_index=left_index,
#    9851         right_index=right_index,
#    9852         sort=sort,
#    9853         suffixes=suffixes,
#    9854         copy=copy,
#    9855         indicator=indicator,
#    9856         validate=validate,
#    9857     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:162, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
#     148     op = _MergeOperation(
#     149         left,
#     150         right,
#    (...)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.get_result(self, copy)
#     805 def get_result(self, copy: bool | None = True) -> DataFrame:
#     806     if self.indicator:
# --> 807         self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     809     join_index, left_indexer, right_indexer = self._get_join_info()
#     811     result = self._reindex_and_concat(
#     812         join_index, left_indexer, right_indexer, copy=copy
#     813     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:856, in _MergeOperation._indicator_pre_merge(self, left, right)
#     851         raise ValueError(
#     852             "Cannot use `indicator=True` option when "
#     853             f"data contains a column named {i}"
#     854         )
#     855 if self._indicator_name in columns:
# --> 856     raise ValueError(
#     857         "Cannot use name of an existing column for indicator column"
#     858     )
#     860 left = left.copy()
#     861 right = right.copy()
#
# ValueError: Cannot use name of an existing column for indicator column

# %%
df_merged.to_csv(path+"\orders_products_merged.csv")
