# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
orders_products_merged = pd.read_csv(r"C:\Users\danie\_orders_products\orders_products_merged.csv")

# %%
path= r"C:\Users\danie\_orders_products\orders_products_merged.csv"

# %%
orders_products_merged.shape
# Out:
# (32404859, 18)

# %%
orders_products_merged.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0           0             0   2539329        1    prior             1
# 1           1             5   2398795        1    prior             2
# 2           2            11    473747        1    prior             3
# 3           3            16   2254736        1    prior             4
# 4           4            21    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          3                  7                    15.0         196
# 2          3                 12                    21.0         196
# 3          4                  7                    29.0         196
# 4          4                 15                    28.0         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
# Create a subset
df = orders_products_merged [:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df['prices'].max()
# Out:
# 14.8

# %%
orders_products_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in orders_products_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
orders_products_merged['busiest_day']= result

# %%
orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
result = []

for value in orders_products_merged["order_dow"]:
  if value == 0:
    result.append("Busiest days")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
orders_products_merged['busiest_days']= result

# %%
orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    22416875
# Busiest days       6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
result = []

for value in orders_products_merged["order_dow"]:
  if value == 0:
    result.append("slowest days")
  elif value == 4:
    result.append("Least slow")
  else:
    result.append("Regularly slow")

# %%
result
# Out:
# ['Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Least slow',
#  'Least slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Least slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Least slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Least slow',
#  'Least slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
#  'Regularly slow',
# ...

# %%
orders_products_merged['slowest_days']= result

# %%
orders_products_merged['slowest_days'].value_counts(dropna = False)
# Out:
# slowest_days
# Regularly slow    22416875
# slowest days       6204182
# Least slow         3783802
# Name: count, dtype: int64

# %% [markdown]
# The output has not chancged from the busiest days to slowest.

# %%
orders_products_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
result = []

for value in orders_products_merged["order_hour_of_day"]:
  if value == 0:
    result.append("most_orders")
  elif value == 4:
    result.append("Average orders")
  else:
    result.append("fewest orders")

# %%
result
# Out:
# ['fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
#  'fewest orders',
# ...

# %%
orders_products_merged.to_csv(r"C:\Users\danie\_orders_products\orders_products_merged.csv")
